# %% [markdown]
# ## A pretty cool notebook

# %%
import math
for i in range(31):
    y = i - 15; x = round(15*math.cos(math.asin(y/15.)))
    print(2*(15-x)*' ', 2*2*x*'=',2*(15-x)*' ')
# Out:
#
# ...
